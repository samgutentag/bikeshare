# %% [markdown]
# # Data Investigation - Stations

# %%
# %matplotlib inline

import matplotlib
import numpy as np
from scipy import stats
import math
import matplotlib.pyplot as plt
import pandas as pd
from glob import glob

import seaborn as sns
sns.set()

# %% [markdown]
# ### Import Data

# %%
print('Loading Station Data...')

try:
    file = 'station_data_clean.csv'
    
    station_import = pd.read_csv('../junk.csv')
except:
    try:
        file_path_slug = '../../../datasets/bayareabikeshare/*_station_data.csv'
        file_list = glob(file_path_slug)

        station_import = pd.DataFrame()

        counter = 1
        chunks = []

        for file in file_list:
            for chunk in pd.read_csv(file, chunksize=10000, iterator=True):
                chunk.columns = ['station_id', 'name', 'lat', 'long', 'dockcount', 'landmark', 'installation']            
                chunks.append(chunk)
            print('\tFinished file! (%d of %d)' % (counter, len(file_list)))
            counter += 1

        station_import = pd.concat(chunks)
        print('Data Loaded Successfully!')
    except:
        print('oops... something went wrong importing the data :(')
# Out:
# Loading Station Data...
# 	Finished file! (1 of 4)
# 	Finished file! (2 of 4)
# 	Finished file! (3 of 4)
# 	Finished file! (4 of 4)
# Data Loaded Successfully!

# %%
def label_zip(row):
    if row['landmark'] == 'San Francisco':
       return '94107'
    if row['landmark'] == 'Redwood City':
        return '94063'
    if row['landmark'] == 'Palo Alto':
        return '94301'
    if row['landmark'] == 'Mountain View':
        return '94041'
    if row['landmark'] == 'San Jose':
        return '95113'
    return '99999'

def make_lat_long(row):
    lat = row['lat']
    long = row['long']
    return (lat, long)

# %%
test = station_import.copy()

# %%
test.sort_values('station_id', inplace=True)

# %%
print('Station Data Cleanup Started...')

station_data = station_import.copy()

# remove dulplicates
print('\tdropping empty rows')
station_data.dropna(how='all', inplace=True)

# set datatype for each column
print('\tset datatype for each column')
station_data['station_id']   = station_data['station_id'].astype('int')
station_data['name']         = station_data['name'].astype('str')
station_data['lat']          = station_data['lat'].astype('float')
station_data['long']         = station_data['long'].astype('float')
station_data['landmark']     = station_data['landmark'].astype('category')

# add a zipcode column for later comparison with weather data
station_data['zip_code'] = station_data.apply(lambda row: label_zip (row),axis=1)
# station_data['zip_code'] = station_data['landmark'].astype('str')

# create lat,lon tuple column
station_data['lat_long'] = station_data.apply(lambda row: make_lat_long (row),axis=1)

print('Cleaning complete!')
# Out:
# Station Data Cleanup Started...
# 	dropping empty rows
# 	set datatype for each column
# Cleaning complete!

# %%
station_data.head(100)
# Out:
#     station_id                                   name        lat        long  \
# 0            2      San Jose Diridon Caltrain Station  37.329732 -121.901782
# 1            3                  San Jose Civic Center  37.330698 -121.888979
# 2            4                 Santa Clara at Almaden  37.333988 -121.894902
# 3            5                       Adobe on Almaden  37.331415 -121.893200
# 4            6                       San Pedro Square  37.336721 -121.894074
# 5            7                   Paseo de San Antonio  37.333798 -121.886943
# 6            8                    San Salvador at 1st  37.330165 -121.885831
# 7            9                              Japantown  37.348742 -121.894715
# 29       15.0      Palo Alto    8/14/2013    94301
#
#                                      lat_long
# 0            (37.329732, -121.90178200000001)
# 1                    (37.330698, -121.888979)
# 2                    (37.333988, -121.894902)
# 3                      (37.331415, -121.8932)
# 4           (37.336721000000004, -121.894074)
# 5            (37.333798, -121.88694299999999)
# 6            (37.330165, -121.88583100000001)
# 7            (37.348742, -121.89471499999999)
# 8                    (37.337391, -121.886995)
# 9            (37.335885, -121.88566000000002)
# 10           (37.332808, -121.88389099999999)
# 11           (37.339301, -121.88993700000002)
# 12                   (37.332692, -121.900084)
# 13          (37.333954999999996, -121.877349)
# 14                   (37.481758, -122.226904)
# 15  (37.486078000000006, -122.23208899999999)
# 16           (37.488501, -122.23106100000001)
# 17                   (37.484219, -122.227424)
# 18                   (37.486725, -122.225551)
# 19                   (37.487682, -122.223492)
# 20                   (37.389218, -122.081896)
# 21  (37.394358000000004, -122.07671299999998)
# 22  (37.406940000000006, -122.10675800000001)
# 23          (37.390277000000005, -122.066553)
# 24           (37.400443, -122.10833799999999)
# 25                   (37.385956, -122.083678)
# 26          (37.400240999999994, -122.099076)
# 27                   (37.443988, -122.164759)
# 28           (37.444521, -122.16309299999999)
# 29           (37.429082, -122.14280500000001)
# ..                                        ...
# 0            (37.329732, -121.90178200000001)
# 1                    (37.330698, -121.888979)
# 2                    (37.333988, -121.894902)
# 3                      (37.331415, -121.8932)
# 4           (37.336721000000004, -121.894074)
# 5            (37.333798, -121.88694299999999)
# 6            (37.330165, -121.88583100000001)
# 7            (37.348742, -121.89471499999999)
# 8                    (37.337391, -121.886995)
# 9            (37.335885, -121.88566000000002)
# 10           (37.332808, -121.88389099999999)
# 11           (37.339301, -121.88993700000002)
# 12                   (37.332692, -121.900084)
# 13          (37.333954999999996, -121.877349)
# 14                   (37.481758, -122.226904)
# 15  (37.486078000000006, -122.23208899999999)
# 16           (37.488501, -122.23106100000001)
# 17                   (37.484219, -122.227424)
# 18                   (37.486725, -122.225551)
# 19                   (37.487682, -122.223492)
# 20                   (37.389218, -122.081896)
# 21  (37.394358000000004, -122.07671299999998)
# 22  (37.406940000000006, -122.10675800000001)
# 23          (37.390277000000005, -122.066553)
# 24           (37.400443, -122.10833799999999)
# 25                   (37.385956, -122.083678)
# 26          (37.400240999999994, -122.099076)
# 27                   (37.443988, -122.164759)
# 28           (37.444521, -122.16309299999999)
# 29           (37.429082, -122.14280500000001)
#
# [100 rows x 9 columns]

# %%
station_data.reset_index(inplace=True)
station_data.sort_values(by=['station_id', 'installation'], inplace=True)

# %%
station_data
# Out:
#     station_id                                           name        lat  \
# 0            2              San Jose Diridon Caltrain Station  37.329732
# 1            3                          San Jose Civic Center  37.330698
# 2            4                         Santa Clara at Almaden  37.333988
# 3            5                               Adobe on Almaden  37.331415
# 4            6                               San Pedro Square  37.336721
# 5            7                           Paseo de San Antonio  37.333798
# 67 -122.400862       15.0  San Francisco    1/22/2014    94107
# 68 -122.236234       15.0   Redwood City    2/20/2014    94063
# 69 -121.895617       15.0       San Jose     4/9/2014    95113
# 70 -121.881630       19.0       San Jose       6/5/16    95113
# 71 -121.890429       19.0       San Jose       6/5/16    95113
# 72 -122.403158       31.0  San Francisco       8/4/16    94107
# 73 -122.408891       35.0  San Francisco       8/4/16    94107
#
#                                      lat_long
# 0            (37.329732, -121.90178200000001)
# 1                    (37.330698, -121.888979)
# 2                    (37.333988, -121.894902)
# 3                      (37.331415, -121.8932)
# 4           (37.336721000000004, -121.894074)
# 5            (37.333798, -121.88694299999999)
# 6            (37.330165, -121.88583100000001)
# 7            (37.348742, -121.89471499999999)
# 8                    (37.337391, -121.886995)
# 9            (37.335885, -121.88566000000002)
# 10           (37.332808, -121.88389099999999)
# 11           (37.339301, -121.88993700000002)
# 12                   (37.332692, -121.900084)
# 13          (37.333954999999996, -121.877349)
# 14                   (37.481758, -122.226904)
# 15  (37.486078000000006, -122.23208899999999)
# 16           (37.488501, -122.23106100000001)
# 17                   (37.484219, -122.227424)
# 18                   (37.486725, -122.225551)
# 19                   (37.487682, -122.223492)
# 20                   (37.389218, -122.081896)
# 21  (37.394358000000004, -122.07671299999998)
# 22  (37.406940000000006, -122.10675800000001)
# 23          (37.390277000000005, -122.066553)
# 24           (37.400443, -122.10833799999999)
# 25                   (37.385956, -122.083678)
# 26          (37.400240999999994, -122.099076)
# 27                   (37.443988, -122.164759)
# 28           (37.444521, -122.16309299999999)
# 29           (37.429082, -122.14280500000001)
# ..                                        ...
# 44           (37.792251, -122.39708600000002)
# 45  (37.781752000000004, -122.40512700000001)
# 46            (37.77865, -122.41823500000001)
# 47                   (37.781332, -122.418603)
# 48            (37.80477, -122.40323400000001)
# 49           (37.780526, -122.39028799999998)
# 50           (37.785299, -122.39623600000002)
# 51  (37.786978000000005, -122.39810800000001)
# 52                   (37.782259, -122.392738)
# 53          (37.771058000000004, -122.402717)
# 54                   (37.774814, -122.418954)
# 55  (37.776619000000004, -122.41738500000001)
# 56  (37.784878000000006, -122.40101399999999)
# 57           (37.776377000000004, -122.39607)
# 58           (37.776617, -122.39526000000001)
# 59                   (37.788446, -122.408499)
# 60           (37.780356, -122.41291899999999)
# 61                     (37.7979, -122.405942)
# 62                   (37.794139, -122.394434)
# 63                     (37.7913, -122.399051)
# 64           (37.786305, -122.40496599999999)
# 65                   (37.789625, -122.400811)
# 66           (37.352601, -121.90573300000001)
# 67           (37.798541, -122.40086200000002)
# 68           (37.491269, -122.23623400000001)
# 69           (37.342725, -121.89561699999999)
# 70                    (37.331957, -121.88163)
# 71                   (37.332398, -121.890429)
# 72                   (37.780148, -122.403158)
# 73                   (37.785908, -122.408891)
#
# [74 rows x 9 columns]

# %%
# drop identical columns, keep first
station_data.drop_duplicates(station_data.columns, keep='first', inplace=True)

# drop remaining columns with matching station_id values, keep first
station_data.drop_duplicates(['station_id'], keep='first', inplace=True)

# %%
station_data.head()
# Out:
#    station_id                               name        lat        long  \
# 0           2  San Jose Diridon Caltrain Station  37.329732 -121.901782
# 1           3              San Jose Civic Center  37.330698 -121.888979
# 2           4             Santa Clara at Almaden  37.333988 -121.894902
# 3           5                   Adobe on Almaden  37.331415 -121.893200
# 4           6                   San Pedro Square  37.336721 -121.894074
#
#    dockcount  landmark installation zip_code  \
# 0       27.0  San Jose     8/6/2013    95113
# 1       15.0  San Jose     8/5/2013    95113
# 2       11.0  San Jose     8/6/2013    95113
# 3       19.0  San Jose     8/5/2013    95113
# 4       15.0  San Jose     8/7/2013    95113
#
#                             lat_long
# 0   (37.329732, -121.90178200000001)
# 1           (37.330698, -121.888979)
# 2           (37.333988, -121.894902)
# 3             (37.331415, -121.8932)
# 4  (37.336721000000004, -121.894074)

# %%
station_data.sort_values(by=['station_id', 'installation'], inplace=True)
station_data.set_index('station_id', inplace=True)

station_data.head()
# Out:
#                                          name        lat        long  \
# station_id
# 2           San Jose Diridon Caltrain Station  37.329732 -121.901782
# 3                       San Jose Civic Center  37.330698 -121.888979
# 4                      Santa Clara at Almaden  37.333988 -121.894902
# 5                            Adobe on Almaden  37.331415 -121.893200
# 6                            San Pedro Square  37.336721 -121.894074
#
#             dockcount  landmark installation zip_code  \
# station_id
# 2                27.0  San Jose     8/6/2013    95113
# 3                15.0  San Jose     8/5/2013    95113
# 4                11.0  San Jose     8/6/2013    95113
# 5                19.0  San Jose     8/5/2013    95113
# 6                15.0  San Jose     8/7/2013    95113
#
#                                      lat_long
# station_id
# 2            (37.329732, -121.90178200000001)
# 3                    (37.330698, -121.888979)
# 4                    (37.333988, -121.894902)
# 5                      (37.331415, -121.8932)
# 6           (37.336721000000004, -121.894074)

# %%
station_data.to_csv('../../../datasets/bayareabikeshare/CLEANED/station_data_cleaned.csv', encoding='utf-8')
station_data.to_csv('../clean_data/station_data_cleaned.csv', encoding='utf-8')

# %%
station_data.head()
# Out:
#                                          name        lat        long  \
# station_id
# 2           San Jose Diridon Caltrain Station  37.329732 -121.901782
# 3                       San Jose Civic Center  37.330698 -121.888979
# 4                      Santa Clara at Almaden  37.333988 -121.894902
# 5                            Adobe on Almaden  37.331415 -121.893200
# 6                            San Pedro Square  37.336721 -121.894074
#
#             dockcount  landmark installation zip_code  \
# station_id
# 2                27.0  San Jose     8/6/2013    95113
# 3                15.0  San Jose     8/5/2013    95113
# 4                11.0  San Jose     8/6/2013    95113
# 5                19.0  San Jose     8/5/2013    95113
# 6                15.0  San Jose     8/7/2013    95113
#
#                                      lat_long
# station_id
# 2            (37.329732, -121.90178200000001)
# 3                    (37.330698, -121.888979)
# 4                    (37.333988, -121.894902)
# 5                      (37.331415, -121.8932)
# 6           (37.336721000000004, -121.894074)
